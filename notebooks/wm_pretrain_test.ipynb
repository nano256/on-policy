# %%
import argparse
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F

from gym import spaces


from onpolicy.algorithms.r_mappo.algorithm.intention_sharing import IntentionSharingModel
from onpolicy.envs.env_wrappers import SubprocVecEnv, DummyVecEnv
from onpolicy.envs.mpe.MPE_env import MPEEnv
from onpolicy.config import get_config

# %%
def preprocess_actions(actions):
        if actions.dim() == 5:
            # We assume actions having the dims (Rollout, Sequence, Batch, Agent, Features)
            action_shape = actions.shape
            n_agents = actions.size(3)
            own_action = []
            other_actions = []
            for idx in range(n_agents):
                mask = torch.ones_like(actions)
                mask[..., idx, :] = 0
                mask = mask == 1
                other_actions.append(actions[mask].reshape(*action_shape[:3], 1, -1))
                # We want to keep the agent dim
                own_action.append(actions[..., idx : idx + 1, :])
            other_actions = torch.cat(other_actions, 3)
            own_action = torch.cat(own_action, 3)
            all_actions = torch.cat((own_action, other_actions), -1)
        elif actions.dim() == 4:
            # We assume actions having the dims (Seq, Batch, Agent, Features)
            action_shape = actions.shape
            n_agents = actions.shape[2]
            own_action = []
            other_actions = []
            for idx in range(n_agents):
                mask = torch.ones_like(actions)
                mask[:, :, idx, :] = 0
                mask = mask == 1
                other_actions.append(actions[mask].reshape(*action_shape[:2], 1, -1))
                # We want to keep the agent dim
                own_action.append(actions[..., idx : idx + 1, :])
            other_actions = torch.cat(other_actions, 2)
            own_action = torch.cat(own_action, 2)
            all_actions = torch.cat((own_action, other_actions), -1)
        else:
            ValueError(
                f"Input expected to have 4 or 5 dimensions, got {actions.dim()} instead."
            )
        return all_actions

# %%
def pretrain_world_model(
        policy, env, n_agents, n_samples, batch_size, n_episodes
    ):
        # Since each env step gives the number of agents in samples
        samples_per_env_step = n_agents * env.num_envs
        obs_batch = []
        action_batch = []
        # env reset only gives back the first observation
        obs = env.reset()
        obs_rollout = [obs]
        action_rollout = []
        n_actions = env.action_space[0].n
        actions_per_step = np.product(obs.shape[:-1])
        obs_predictor = policy.actor.observation_predictor
        optim = policy.obs_predictor_optimizer
        collected_samples = 0
        # Collect observations from random trajectories
        while True:
            random_actions = torch.randint(n_actions, (actions_per_step,)).reshape(
                (*obs.shape[:-1], 1)
            )
            random_actions = F.one_hot(random_actions, n_actions).squeeze(-2)
            obs, _, dones, _ = env.step(random_actions)
            obs_rollout.append(obs)
            action_rollout.append(random_actions.numpy())
            if np.any(dones):
                obs_batch.append(obs_rollout)
                action_batch.append(action_rollout)
                collected_samples += len(action_rollout) * samples_per_env_step
                if collected_samples >= n_samples:
                    break
                obs_rollout = [env.reset()]
                action_rollout = []

        obs_batch = torch.Tensor(np.array(obs_batch))
        action_batch = torch.Tensor(np.array(action_batch))
        action_batch = preprocess_actions(action_batch)
        # To ensure that the timesteps in the train batches are in correct order, we have to transpose the obs tensor
        perm_seq = (0, 2, 3, 1, 4)
        obs_batch = obs_batch.permute(perm_seq)
        action_batch = action_batch.permute(perm_seq)
        # Take all obs except the last of each episode as the input data
        initial_obs = obs_batch[..., :-1, :]
        x_train = torch.cat((initial_obs, action_batch), -1)
        x_train = x_train.reshape(-1, x_train.size(-1))[:n_samples].to(
            **policy.actor.tpdv
        )
        # Take all consecutive obs of x as our labels
        y_train = (
            obs_batch[..., 1:, :]
            .reshape(-1, obs_batch.size(-1))[:n_samples]
            .to(**policy.actor.tpdv)
        )
        initial_obs_train = initial_obs.reshape(-1, obs_batch.size(-1))[:n_samples].to(
            **policy.actor.tpdv
        )

        n_batches = n_samples // batch_size

        loss_fn = nn.MSELoss()
        steps = 0
        for _ in range(n_episodes):
            samples = torch.randperm(n_samples)
            for n_batch in range(n_batches):
                optim.zero_grad()
                idx = samples[batch_size * n_batch : batch_size * (n_batch + 1)]
                x = x_train[idx]
                x_obs = initial_obs_train[idx]
                y = y_train[idx]
                # The observation predictor infers the the difference between current and next observation. Therefore we add the current obs to the output.
                y_pred = obs_predictor(x) + x_obs
                loss = loss_fn(y_pred, y)
                loss.backward()
                optim.step()
                print(f"WM obs. predictor loss at step {steps}: {loss:.4f}")
                steps += batch_size

# %%
def make_train_env(all_args):
    def get_env_fn(rank):
        def init_env():
            if all_args.env_name == "MPE":
                env = MPEEnv(all_args)
            else:
                print("Can not support the " + all_args.env_name + "environment.")
                raise NotImplementedError
            env.seed(all_args.seed + rank * 1000)
            return env

        return init_env

    if all_args.n_rollout_threads == 1:
        return DummyVecEnv([get_env_fn(0)])
    else:
        return SubprocVecEnv([get_env_fn(i) for i in range(all_args.n_rollout_threads)])

# %%
def make_args(args_dict):  
    args = argparse.Namespace()
    for key, value in args_dict.items():
        setattr(args, key, value)
    return args

# %%
class Policy(nn.Module):

    def __init__(self, args, envs):
        super().__init__()

        self.actor = IntentionSharingModel(
            args,
            envs.observation_space[0],
            envs.action_space[0],
            spaces.Box(-np.inf, np.inf, (32,)),
            args.num_agents,
            torch.device('cpu'),
    )
        self.obs_predictor_optimizer = torch.optim.Adam(self.actor.observation_predictor.parameters(), 1e-3)

# %%
args_dict = {
        'env_name': "MPE",
        'use_obs_instead_of_state': False,
        'scenario_name': 'simple_spread',
        'num_agents': 3,
        'num_landmarks': 3, 
        'n_training_threads': 1,
        'n_rollout_threads': 1,
        'episode_length': 25,
        'use_local_obs': False,
        'seed': 1,
        'hidden_size': 64,
        'recurrent_N': 2,
        'gain': 0.01,
        'use_orthogonal': True,
        'use_policy_active_masks': False,
        'use_naive_recurrent_policy': False,
        'use_recurrent_policy': False,
        'intention_aggregation': 'mean',
        'imagined_traj_len': 4,
        'communication_interval': 4,
        'use_feature_normalization': True,
        'use_ReLU': True,
        'stacked_frames': 1,
        'layer_N': 1,
        
        }

# %%
args = make_args(args_dict)
envs = make_train_env(args)
policy = Policy(args, envs)

# %%
pretrain_world_model(policy, envs, args.num_agents, 1000, 100, 10)
# Out:
# WM obs. predictor loss at step 0: 0.4095
# WM obs. predictor loss at step 100: 0.3127
# WM obs. predictor loss at step 200: 0.3328
# WM obs. predictor loss at step 300: 0.2353
# WM obs. predictor loss at step 400: 0.2380
# WM obs. predictor loss at step 500: 0.2468
# WM obs. predictor loss at step 600: 0.1781
# WM obs. predictor loss at step 700: 0.1631
# WM obs. predictor loss at step 800: 0.1965
# WM obs. predictor loss at step 900: 0.1878
# WM obs. predictor loss at step 1000: 0.1896
# WM obs. predictor loss at step 1100: 0.1534
# WM obs. predictor loss at step 1200: 0.0988
# WM obs. predictor loss at step 1300: 0.1247
# WM obs. predictor loss at step 1400: 0.0802
# WM obs. predictor loss at step 1500: 0.0786
# WM obs. predictor loss at step 1600: 0.1176
# WM obs. predictor loss at step 1700: 0.1213
# WM obs. predictor loss at step 1800: 0.1578
# WM obs. predictor loss at step 1900: 0.0858
# WM obs. predictor loss at step 2000: 0.1187
# WM obs. predictor loss at step 2100: 0.0855
# WM obs. predictor loss at step 2200: 0.0537
# WM obs. predictor loss at step 2300: 0.0864
# WM obs. predictor loss at step 2400: 0.0815
# WM obs. predictor loss at step 2500: 0.1353
# WM obs. predictor loss at step 2600: 0.1218
# WM obs. predictor loss at step 2700: 0.1264
# WM obs. predictor loss at step 2800: 0.0825
# WM obs. predictor loss at step 2900: 0.0626
# WM obs. predictor loss at step 3000: 0.0667
# WM obs. predictor loss at step 3100: 0.0563
# WM obs. predictor loss at step 3200: 0.0618
# WM obs. predictor loss at step 3300: 0.0466
# WM obs. predictor loss at step 3400: 0.0354
# WM obs. predictor loss at step 3500: 0.0456
# WM obs. predictor loss at step 3600: 0.1099
# WM obs. predictor loss at step 3700: 0.0642
# WM obs. predictor loss at step 3800: 0.0373
# WM obs. predictor loss at step 3900: 0.0847
# WM obs. predictor loss at step 4000: 0.0477
# WM obs. predictor loss at step 4100: 0.0396
# WM obs. predictor loss at step 4200: 0.1207
# WM obs. predictor loss at step 4300: 0.0633
# WM obs. predictor loss at step 4400: 0.0428
# WM obs. predictor loss at step 4500: 0.0870
# WM obs. predictor loss at step 4600: 0.0455
# WM obs. predictor loss at step 4700: 0.0689
# WM obs. predictor loss at step 4800: 0.0954
# WM obs. predictor loss at step 4900: 0.0715
# WM obs. predictor loss at step 5000: 0.0630
# WM obs. predictor loss at step 5100: 0.0201
# WM obs. predictor loss at step 5200: 0.0385
# WM obs. predictor loss at step 5300: 0.0388
# WM obs. predictor loss at step 5400: 0.0640
# WM obs. predictor loss at step 5500: 0.0750
# WM obs. predictor loss at step 5600: 0.0917
# WM obs. predictor loss at step 5700: 0.0482
# WM obs. predictor loss at step 5800: 0.0437
# WM obs. predictor loss at step 5900: 0.0487
# WM obs. predictor loss at step 6000: 0.0414
# WM obs. predictor loss at step 6100: 0.0741
# WM obs. predictor loss at step 6200: 0.0583
# WM obs. predictor loss at step 6300: 0.0615
# WM obs. predictor loss at step 6400: 0.0357
# WM obs. predictor loss at step 6500: 0.0759
# WM obs. predictor loss at step 6600: 0.0452
# WM obs. predictor loss at step 6700: 0.0516
# WM obs. predictor loss at step 6800: 0.0678
# WM obs. predictor loss at step 6900: 0.0471
# WM obs. predictor loss at step 7000: 0.0599
# WM obs. predictor loss at step 7100: 0.0213
# WM obs. predictor loss at step 7200: 0.0179
# WM obs. predictor loss at step 7300: 0.0783
# WM obs. predictor loss at step 7400: 0.0606
# WM obs. predictor loss at step 7500: 0.0771
# WM obs. predictor loss at step 7600: 0.0556
# WM obs. predictor loss at step 7700: 0.0525
# WM obs. predictor loss at step 7800: 0.0234
# WM obs. predictor loss at step 7900: 0.0247
# WM obs. predictor loss at step 8000: 0.0645
# WM obs. predictor loss at step 8100: 0.0683
# WM obs. predictor loss at step 8200: 0.0867
# WM obs. predictor loss at step 8300: 0.0627
# WM obs. predictor loss at step 8400: 0.0688
# WM obs. predictor loss at step 8500: 0.0837
# WM obs. predictor loss at step 8600: 0.0622
# WM obs. predictor loss at step 8700: 0.0685
# WM obs. predictor loss at step 8800: 0.0541
# WM obs. predictor loss at step 8900: 0.0304
# WM obs. predictor loss at step 9000: 0.0459
# WM obs. predictor loss at step 9100: 0.0680
# WM obs. predictor loss at step 9200: 0.0308
# WM obs. predictor loss at step 9300: 0.0499
# WM obs. predictor loss at step 9400: 0.0327
# WM obs. predictor loss at step 9500: 0.0932
# WM obs. predictor loss at step 9600: 0.0349
# WM obs. predictor loss at step 9700: 0.0371
# WM obs. predictor loss at step 9800: 0.0480
# WM obs. predictor loss at step 9900: 0.1219
# WM obs. predictor loss at step 10000: 0.0406
# WM obs. predictor loss at step 10100: 0.0288
# WM obs. predictor loss at step 10200: 0.0794
# WM obs. predictor loss at step 10300: 0.0798
# WM obs. predictor loss at step 10400: 0.0387
# WM obs. predictor loss at step 10500: 0.1259
# WM obs. predictor loss at step 10600: 0.0720
# WM obs. predictor loss at step 10700: 0.0741
# WM obs. predictor loss at step 10800: 0.1195
# WM obs. predictor loss at step 10900: 0.0383
# WM obs. predictor loss at step 11000: 0.0910
# WM obs. predictor loss at step 11100: 0.0373
# WM obs. predictor loss at step 11200: 0.0236
# WM obs. predictor loss at step 11300: 0.0274
# WM obs. predictor loss at step 11400: 0.0509
# WM obs. predictor loss at step 11500: 0.0355
# WM obs. predictor loss at step 11600: 0.0384
# WM obs. predictor loss at step 11700: 0.0532
# WM obs. predictor loss at step 11800: 0.0649
# WM obs. predictor loss at step 11900: 0.0855
# WM obs. predictor loss at step 12000: 0.0311
# WM obs. predictor loss at step 12100: 0.0245
# WM obs. predictor loss at step 12200: 0.0315
# WM obs. predictor loss at step 12300: 0.0553
# WM obs. predictor loss at step 12400: 0.0250
# WM obs. predictor loss at step 12500: 0.0325
# WM obs. predictor loss at step 12600: 0.0283
# WM obs. predictor loss at step 12700: 0.0693
# WM obs. predictor loss at step 12800: 0.0480
# WM obs. predictor loss at step 12900: 0.0855
# WM obs. predictor loss at step 13000: 0.0293
# WM obs. predictor loss at step 13100: 0.0890
# WM obs. predictor loss at step 13200: 0.0543
# WM obs. predictor loss at step 13300: 0.0661
# WM obs. predictor loss at step 13400: 0.0576
# WM obs. predictor loss at step 13500: 0.1021
# WM obs. predictor loss at step 13600: 0.0383
# WM obs. predictor loss at step 13700: 0.0098
# WM obs. predictor loss at step 13800: 0.0344
# WM obs. predictor loss at step 13900: 0.0677
# WM obs. predictor loss at step 14000: 0.0837
# WM obs. predictor loss at step 14100: 0.0565
# WM obs. predictor loss at step 14200: 0.0291
# WM obs. predictor loss at step 14300: 0.1106
# WM obs. predictor loss at step 14400: 0.0391
# WM obs. predictor loss at step 14500: 0.0204
# WM obs. predictor loss at step 14600: 0.0643
# WM obs. predictor loss at step 14700: 0.0941
# WM obs. predictor loss at step 14800: 0.0362
# WM obs. predictor loss at step 14900: 0.0416
# WM obs. predictor loss at step 15000: 0.0431
# WM obs. predictor loss at step 15100: 0.0471
# WM obs. predictor loss at step 15200: 0.0403
# WM obs. predictor loss at step 15300: 0.0601
# WM obs. predictor loss at step 15400: 0.0590
# WM obs. predictor loss at step 15500: 0.0435
# WM obs. predictor loss at step 15600: 0.0377
# WM obs. predictor loss at step 15700: 0.0268
# WM obs. predictor loss at step 15800: 0.0141
# WM obs. predictor loss at step 15900: 0.0211
# WM obs. predictor loss at step 16000: 0.0494
# WM obs. predictor loss at step 16100: 0.0653
# WM obs. predictor loss at step 16200: 0.0597
# WM obs. predictor loss at step 16300: 0.0270
# WM obs. predictor loss at step 16400: 0.0310
# WM obs. predictor loss at step 16500: 0.0257
# WM obs. predictor loss at step 16600: 0.0475
# WM obs. predictor loss at step 16700: 0.0386
# WM obs. predictor loss at step 16800: 0.0298
# WM obs. predictor loss at step 16900: 0.0075
# WM obs. predictor loss at step 17000: 0.0587
# WM obs. predictor loss at step 17100: 0.0327
# WM obs. predictor loss at step 17200: 0.0456
# WM obs. predictor loss at step 17300: 0.0350
# WM obs. predictor loss at step 17400: 0.0594
# WM obs. predictor loss at step 17500: 0.0369
# WM obs. predictor loss at step 17600: 0.0771
# WM obs. predictor loss at step 17700: 0.0429
# WM obs. predictor loss at step 17800: 0.1002
# WM obs. predictor loss at step 17900: 0.0164
# WM obs. predictor loss at step 18000: 0.0959
# WM obs. predictor loss at step 18100: 0.0894
# WM obs. predictor loss at step 18200: 0.0731
# WM obs. predictor loss at step 18300: 0.0779
# WM obs. predictor loss at step 18400: 0.0549
# WM obs. predictor loss at step 18500: 0.0535
# WM obs. predictor loss at step 18600: 0.0541
# WM obs. predictor loss at step 18700: 0.0554
# WM obs. predictor loss at step 18800: 0.0442
# WM obs. predictor loss at step 18900: 0.1079
# WM obs. predictor loss at step 19000: 0.0168
# WM obs. predictor loss at step 19100: 0.0181
# WM obs. predictor loss at step 19200: 0.0908
# WM obs. predictor loss at step 19300: 0.0618
# WM obs. predictor loss at step 19400: 0.0079
# WM obs. predictor loss at step 19500: 0.0259
# WM obs. predictor loss at step 19600: 0.0356
# WM obs. predictor loss at step 19700: 0.0337
# WM obs. predictor loss at step 19800: 0.0477
# WM obs. predictor loss at step 19900: 0.0726
# WM obs. predictor loss at step 20000: 0.0481
# WM obs. predictor loss at step 20100: 0.0679
# WM obs. predictor loss at step 20200: 0.0609
# WM obs. predictor loss at step 20300: 0.0057
# WM obs. predictor loss at step 20400: 0.0149
# WM obs. predictor loss at step 20500: 0.0807
# WM obs. predictor loss at step 20600: 0.1290
# WM obs. predictor loss at step 20700: 0.0561
# WM obs. predictor loss at step 20800: 0.0641
# WM obs. predictor loss at step 20900: 0.0176
# WM obs. predictor loss at step 21000: 0.0429
# WM obs. predictor loss at step 21100: 0.0569
# WM obs. predictor loss at step 21200: 0.0267
# WM obs. predictor loss at step 21300: 0.0533
# WM obs. predictor loss at step 21400: 0.0326
# WM obs. predictor loss at step 21500: 0.0274
# WM obs. predictor loss at step 21600: 0.0820
# WM obs. predictor loss at step 21700: 0.0497
# WM obs. predictor loss at step 21800: 0.0212
# WM obs. predictor loss at step 21900: 0.0502
# WM obs. predictor loss at step 22000: 0.0445
# WM obs. predictor loss at step 22100: 0.0376
# WM obs. predictor loss at step 22200: 0.0571
# WM obs. predictor loss at step 22300: 0.0228
# WM obs. predictor loss at step 22400: 0.0536
# WM obs. predictor loss at step 22500: 0.0386
# WM obs. predictor loss at step 22600: 0.0518
# WM obs. predictor loss at step 22700: 0.0611
# WM obs. predictor loss at step 22800: 0.0673
# WM obs. predictor loss at step 22900: 0.1032
# WM obs. predictor loss at step 23000: 0.0322
# WM obs. predictor loss at step 23100: 0.0598
# WM obs. predictor loss at step 23200: 0.0148
# WM obs. predictor loss at step 23300: 0.0334
# WM obs. predictor loss at step 23400: 0.0087
# WM obs. predictor loss at step 23500: 0.0604
# WM obs. predictor loss at step 23600: 0.0526
# WM obs. predictor loss at step 23700: 0.0550
# WM obs. predictor loss at step 23800: 0.0679
# WM obs. predictor loss at step 23900: 0.0329
# WM obs. predictor loss at step 24000: 0.0372
# WM obs. predictor loss at step 24100: 0.0633
# WM obs. predictor loss at step 24200: 0.0892
# WM obs. predictor loss at step 24300: 0.0089
# WM obs. predictor loss at step 24400: 0.0536
# WM obs. predictor loss at step 24500: 0.0679
# WM obs. predictor loss at step 24600: 0.0776
# WM obs. predictor loss at step 24700: 0.0331
# WM obs. predictor loss at step 24800: 0.0688
# WM obs. predictor loss at step 24900: 0.0368
# WM obs. predictor loss at step 25000: 0.0730
# WM obs. predictor loss at step 25100: 0.0220
# WM obs. predictor loss at step 25200: 0.0651
# WM obs. predictor loss at step 25300: 0.0390
# WM obs. predictor loss at step 25400: 0.0206
# WM obs. predictor loss at step 25500: 0.0590
# WM obs. predictor loss at step 25600: 0.0180
# WM obs. predictor loss at step 25700: 0.0082
# WM obs. predictor loss at step 25800: 0.0291
# WM obs. predictor loss at step 25900: 0.0498
# WM obs. predictor loss at step 26000: 0.0876
# WM obs. predictor loss at step 26100: 0.0138
# WM obs. predictor loss at step 26200: 0.0669
# WM obs. predictor loss at step 26300: 0.0232
# WM obs. predictor loss at step 26400: 0.0116
# WM obs. predictor loss at step 26500: 0.0241
# WM obs. predictor loss at step 26600: 0.0275
# WM obs. predictor loss at step 26700: 0.0599
# WM obs. predictor loss at step 26800: 0.0224
# WM obs. predictor loss at step 26900: 0.0538
# WM obs. predictor loss at step 27000: 0.0970
# WM obs. predictor loss at step 27100: 0.0428
# WM obs. predictor loss at step 27200: 0.0232
# WM obs. predictor loss at step 27300: 0.0465
# WM obs. predictor loss at step 27400: 0.0046
# WM obs. predictor loss at step 27500: 0.0264
# WM obs. predictor loss at step 27600: 0.0565
# WM obs. predictor loss at step 27700: 0.0441
# WM obs. predictor loss at step 27800: 0.0843
# WM obs. predictor loss at step 27900: 0.0565
# WM obs. predictor loss at step 28000: 0.0977
# WM obs. predictor loss at step 28100: 0.0209
# WM obs. predictor loss at step 28200: 0.0750
# WM obs. predictor loss at step 28300: 0.0582
# WM obs. predictor loss at step 28400: 0.0054
# WM obs. predictor loss at step 28500: 0.0379
# WM obs. predictor loss at step 28600: 0.0899
# WM obs. predictor loss at step 28700: 0.0336
# WM obs. predictor loss at step 28800: 0.0541
# WM obs. predictor loss at step 28900: 0.0891
# WM obs. predictor loss at step 29000: 0.0460
# WM obs. predictor loss at step 29100: 0.0214
# WM obs. predictor loss at step 29200: 0.0303
# WM obs. predictor loss at step 29300: 0.0621
# WM obs. predictor loss at step 29400: 0.0167
# WM obs. predictor loss at step 29500: 0.0460
# WM obs. predictor loss at step 29600: 0.0297
# WM obs. predictor loss at step 29700: 0.0659
# WM obs. predictor loss at step 29800: 0.0982
# WM obs. predictor loss at step 29900: 0.0650
# WM obs. predictor loss at step 30000: 0.0594
# WM obs. predictor loss at step 30100: 0.0518
# WM obs. predictor loss at step 30200: 0.1339
# WM obs. predictor loss at step 30300: 0.0455
# WM obs. predictor loss at step 30400: 0.0342
# WM obs. predictor loss at step 30500: 0.0105
# WM obs. predictor loss at step 30600: 0.0340
# WM obs. predictor loss at step 30700: 0.0560
# WM obs. predictor loss at step 30800: 0.0499
# WM obs. predictor loss at step 30900: 0.0728
# WM obs. predictor loss at step 31000: 0.0473
# WM obs. predictor loss at step 31100: 0.0052
# WM obs. predictor loss at step 31200: 0.0222
# WM obs. predictor loss at step 31300: 0.0182
# WM obs. predictor loss at step 31400: 0.0517
# WM obs. predictor loss at step 31500: 0.0497
# WM obs. predictor loss at step 31600: 0.0509
# WM obs. predictor loss at step 31700: 0.0613
# WM obs. predictor loss at step 31800: 0.0333
# WM obs. predictor loss at step 31900: 0.0394
# WM obs. predictor loss at step 32000: 0.0462
# WM obs. predictor loss at step 32100: 0.0255
# WM obs. predictor loss at step 32200: 0.0204
# WM obs. predictor loss at step 32300: 0.0702
# WM obs. predictor loss at step 32400: 0.0311
# WM obs. predictor loss at step 32500: 0.0702
# WM obs. predictor loss at step 32600: 0.0594
# WM obs. predictor loss at step 32700: 0.0308
# WM obs. predictor loss at step 32800: 0.0322
# WM obs. predictor loss at step 32900: 0.0913
# WM obs. predictor loss at step 33000: 0.0547
# WM obs. predictor loss at step 33100: 0.0282
# WM obs. predictor loss at step 33200: 0.0703
# WM obs. predictor loss at step 33300: 0.0488
# WM obs. predictor loss at step 33400: 0.0296
# WM obs. predictor loss at step 33500: 0.0336
# WM obs. predictor loss at step 33600: 0.0432
# WM obs. predictor loss at step 33700: 0.0223
# WM obs. predictor loss at step 33800: 0.0697
# WM obs. predictor loss at step 33900: 0.0266
# WM obs. predictor loss at step 34000: 0.0187
# WM obs. predictor loss at step 34100: 0.0362
# WM obs. predictor loss at step 34200: 0.0618
# WM obs. predictor loss at step 34300: 0.0412
# WM obs. predictor loss at step 34400: 0.0500
# WM obs. predictor loss at step 34500: 0.0556
# WM obs. predictor loss at step 34600: 0.0367
# WM obs. predictor loss at step 34700: 0.0066
# WM obs. predictor loss at step 34800: 0.0665
# WM obs. predictor loss at step 34900: 0.0346
# WM obs. predictor loss at step 35000: 0.0340
# WM obs. predictor loss at step 35100: 0.0889
# WM obs. predictor loss at step 35200: 0.0117
# WM obs. predictor loss at step 35300: 0.0505
# WM obs. predictor loss at step 35400: 0.0836
# WM obs. predictor loss at step 35500: 0.0263
# WM obs. predictor loss at step 35600: 0.0249
# WM obs. predictor loss at step 35700: 0.0229
# WM obs. predictor loss at step 35800: 0.0713
# WM obs. predictor loss at step 35900: 0.0039
# WM obs. predictor loss at step 36000: 0.0545
# WM obs. predictor loss at step 36100: 0.0432
# WM obs. predictor loss at step 36200: 0.0160
# WM obs. predictor loss at step 36300: 0.0657
# WM obs. predictor loss at step 36400: 0.0857
# WM obs. predictor loss at step 36500: 0.0198
# WM obs. predictor loss at step 36600: 0.0293
# WM obs. predictor loss at step 36700: 0.0880
# WM obs. predictor loss at step 36800: 0.0427
# WM obs. predictor loss at step 36900: 0.0589
# WM obs. predictor loss at step 37000: 0.0456
# WM obs. predictor loss at step 37100: 0.0167
# WM obs. predictor loss at step 37200: 0.0269
# WM obs. predictor loss at step 37300: 0.0336
# WM obs. predictor loss at step 37400: 0.0299
# WM obs. predictor loss at step 37500: 0.0072
# WM obs. predictor loss at step 37600: 0.0306
# WM obs. predictor loss at step 37700: 0.0967
# WM obs. predictor loss at step 37800: 0.0690
# WM obs. predictor loss at step 37900: 0.0527
# WM obs. predictor loss at step 38000: 0.0308
# WM obs. predictor loss at step 38100: 0.0414
# WM obs. predictor loss at step 38200: 0.0448
# WM obs. predictor loss at step 38300: 0.0441
# WM obs. predictor loss at step 38400: 0.0563
# WM obs. predictor loss at step 38500: 0.0341
# WM obs. predictor loss at step 38600: 0.1136
# WM obs. predictor loss at step 38700: 0.0783
# WM obs. predictor loss at step 38800: 0.0587
# WM obs. predictor loss at step 38900: 0.0733
# WM obs. predictor loss at step 39000: 0.0450
# WM obs. predictor loss at step 39100: 0.0140
# WM obs. predictor loss at step 39200: 0.0614
# WM obs. predictor loss at step 39300: 0.1124
# WM obs. predictor loss at step 39400: 0.0344
# WM obs. predictor loss at step 39500: 0.0263
# WM obs. predictor loss at step 39600: 0.0451
# WM obs. predictor loss at step 39700: 0.0616
# WM obs. predictor loss at step 39800: 0.0714
# WM obs. predictor loss at step 39900: 0.0366
# WM obs. predictor loss at step 40000: 0.0356
# WM obs. predictor loss at step 40100: 0.0670
# WM obs. predictor loss at step 40200: 0.0573
# WM obs. predictor loss at step 40300: 0.0922
# WM obs. predictor loss at step 40400: 0.0429
# WM obs. predictor loss at step 40500: 0.0257
# WM obs. predictor loss at step 40600: 0.0325
# WM obs. predictor loss at step 40700: 0.0222
# WM obs. predictor loss at step 40800: 0.0437
# WM obs. predictor loss at step 40900: 0.1128
# WM obs. predictor loss at step 41000: 0.0154
# WM obs. predictor loss at step 41100: 0.0301
# WM obs. predictor loss at step 41200: 0.0183
# WM obs. predictor loss at step 41300: 0.0373
# WM obs. predictor loss at step 41400: 0.0226
# WM obs. predictor loss at step 41500: 0.0763
# WM obs. predictor loss at step 41600: 0.0683
# WM obs. predictor loss at step 41700: 0.0560
# WM obs. predictor loss at step 41800: 0.0460
# WM obs. predictor loss at step 41900: 0.0550
# WM obs. predictor loss at step 42000: 0.0794
# WM obs. predictor loss at step 42100: 0.0535
# WM obs. predictor loss at step 42200: 0.0282
# WM obs. predictor loss at step 42300: 0.0706
# WM obs. predictor loss at step 42400: 0.0359
# WM obs. predictor loss at step 42500: 0.0249
# WM obs. predictor loss at step 42600: 0.0629
# WM obs. predictor loss at step 42700: 0.0711
# WM obs. predictor loss at step 42800: 0.0271
# WM obs. predictor loss at step 42900: 0.0505
# WM obs. predictor loss at step 43000: 0.0335
# WM obs. predictor loss at step 43100: 0.0130
# WM obs. predictor loss at step 43200: 0.0436
# WM obs. predictor loss at step 43300: 0.0480
# WM obs. predictor loss at step 43400: 0.0132
# WM obs. predictor loss at step 43500: 0.0498
# WM obs. predictor loss at step 43600: 0.0350
# WM obs. predictor loss at step 43700: 0.0328
# WM obs. predictor loss at step 43800: 0.0126
# WM obs. predictor loss at step 43900: 0.0484
# WM obs. predictor loss at step 44000: 0.0874
# WM obs. predictor loss at step 44100: 0.0438
# WM obs. predictor loss at step 44200: 0.0479
# WM obs. predictor loss at step 44300: 0.0517
# WM obs. predictor loss at step 44400: 0.0569
# WM obs. predictor loss at step 44500: 0.0192
# WM obs. predictor loss at step 44600: 0.0399
# WM obs. predictor loss at step 44700: 0.0606
# WM obs. predictor loss at step 44800: 0.0923
# WM obs. predictor loss at step 44900: 0.0913
# WM obs. predictor loss at step 45000: 0.0161
# WM obs. predictor loss at step 45100: 0.0292
# WM obs. predictor loss at step 45200: 0.0471
# WM obs. predictor loss at step 45300: 0.0447
# WM obs. predictor loss at step 45400: 0.0853
# WM obs. predictor loss at step 45500: 0.0287
# WM obs. predictor loss at step 45600: 0.0145
# WM obs. predictor loss at step 45700: 0.0281
# WM obs. predictor loss at step 45800: 0.0200
# WM obs. predictor loss at step 45900: 0.0033
# WM obs. predictor loss at step 46000: 0.0641
# WM obs. predictor loss at step 46100: 0.0044
# WM obs. predictor loss at step 46200: 0.0602
# WM obs. predictor loss at step 46300: 0.0330
# WM obs. predictor loss at step 46400: 0.0552
# WM obs. predictor loss at step 46500: 0.0062
# WM obs. predictor loss at step 46600: 0.0354
# WM obs. predictor loss at step 46700: 0.0289
# WM obs. predictor loss at step 46800: 0.0837
# WM obs. predictor loss at step 46900: 0.0745
# WM obs. predictor loss at step 47000: 0.0907
# WM obs. predictor loss at step 47100: 0.0558
# WM obs. predictor loss at step 47200: 0.0212
# WM obs. predictor loss at step 47300: 0.0379
# WM obs. predictor loss at step 47400: 0.0404
# WM obs. predictor loss at step 47500: 0.0680
# WM obs. predictor loss at step 47600: 0.0193
# WM obs. predictor loss at step 47700: 0.0428
# WM obs. predictor loss at step 47800: 0.0718
# WM obs. predictor loss at step 47900: 0.0524
# WM obs. predictor loss at step 48000: 0.0214
# WM obs. predictor loss at step 48100: 0.0544
# WM obs. predictor loss at step 48200: 0.0456
# WM obs. predictor loss at step 48300: 0.0334
# WM obs. predictor loss at step 48400: 0.0311
# WM obs. predictor loss at step 48500: 0.0665
# WM obs. predictor loss at step 48600: 0.0196
# WM obs. predictor loss at step 48700: 0.0743
# WM obs. predictor loss at step 48800: 0.0394
# WM obs. predictor loss at step 48900: 0.0538
# WM obs. predictor loss at step 49000: 0.0405
# WM obs. predictor loss at step 49100: 0.0497
# WM obs. predictor loss at step 49200: 0.0619
# WM obs. predictor loss at step 49300: 0.0634
# WM obs. predictor loss at step 49400: 0.0514
# WM obs. predictor loss at step 49500: 0.0703
# WM obs. predictor loss at step 49600: 0.0353
# WM obs. predictor loss at step 49700: 0.0645
# WM obs. predictor loss at step 49800: 0.0555
# WM obs. predictor loss at step 49900: 0.0150
# WM obs. predictor loss at step 50000: 0.0378
# WM obs. predictor loss at step 50100: 0.0250
# WM obs. predictor loss at step 50200: 0.0718
# WM obs. predictor loss at step 50300: 0.0248
# WM obs. predictor loss at step 50400: 0.0262
# WM obs. predictor loss at step 50500: 0.0542
# WM obs. predictor loss at step 50600: 0.0296
# WM obs. predictor loss at step 50700: 0.0401
# WM obs. predictor loss at step 50800: 0.0564
# WM obs. predictor loss at step 50900: 0.0555
# WM obs. predictor loss at step 51000: 0.0588
# WM obs. predictor loss at step 51100: 0.0612
# WM obs. predictor loss at step 51200: 0.1094
# WM obs. predictor loss at step 51300: 0.0290
# WM obs. predictor loss at step 51400: 0.0572
# WM obs. predictor loss at step 51500: 0.0220
# WM obs. predictor loss at step 51600: 0.0150
# WM obs. predictor loss at step 51700: 0.0425
# WM obs. predictor loss at step 51800: 0.1107
# WM obs. predictor loss at step 51900: 0.0620
# WM obs. predictor loss at step 52000: 0.0773
# WM obs. predictor loss at step 52100: 0.0230
# WM obs. predictor loss at step 52200: 0.0583
# WM obs. predictor loss at step 52300: 0.0415
# WM obs. predictor loss at step 52400: 0.0264
# WM obs. predictor loss at step 52500: 0.0640
# WM obs. predictor loss at step 52600: 0.0491
# WM obs. predictor loss at step 52700: 0.0557
# WM obs. predictor loss at step 52800: 0.0561
# WM obs. predictor loss at step 52900: 0.0230
# WM obs. predictor loss at step 53000: 0.0905
# WM obs. predictor loss at step 53100: 0.0407
# WM obs. predictor loss at step 53200: 0.0356
# WM obs. predictor loss at step 53300: 0.0347
# WM obs. predictor loss at step 53400: 0.0674
# WM obs. predictor loss at step 53500: 0.0351
# WM obs. predictor loss at step 53600: 0.0330
# WM obs. predictor loss at step 53700: 0.0378
# WM obs. predictor loss at step 53800: 0.1181
# WM obs. predictor loss at step 53900: 0.0197
# WM obs. predictor loss at step 54000: 0.0487
# WM obs. predictor loss at step 54100: 0.0300
# WM obs. predictor loss at step 54200: 0.0283
# WM obs. predictor loss at step 54300: 0.0466
# WM obs. predictor loss at step 54400: 0.0619
# WM obs. predictor loss at step 54500: 0.0147
# WM obs. predictor loss at step 54600: 0.0248
# WM obs. predictor loss at step 54700: 0.0424
# WM obs. predictor loss at step 54800: 0.0283
# WM obs. predictor loss at step 54900: 0.0452
# WM obs. predictor loss at step 55000: 0.0431
# WM obs. predictor loss at step 55100: 0.1010
# WM obs. predictor loss at step 55200: 0.0517
# WM obs. predictor loss at step 55300: 0.0276
# WM obs. predictor loss at step 55400: 0.0549
# WM obs. predictor loss at step 55500: 0.0300
# WM obs. predictor loss at step 55600: 0.0543
# WM obs. predictor loss at step 55700: 0.0303
# WM obs. predictor loss at step 55800: 0.0204
# WM obs. predictor loss at step 55900: 0.0798
# WM obs. predictor loss at step 56000: 0.0110
# WM obs. predictor loss at step 56100: 0.0450
# WM obs. predictor loss at step 56200: 0.0554
# WM obs. predictor loss at step 56300: 0.0705
# WM obs. predictor loss at step 56400: 0.0473
# WM obs. predictor loss at step 56500: 0.0612
# WM obs. predictor loss at step 56600: 0.0777
# WM obs. predictor loss at step 56700: 0.0438
# WM obs. predictor loss at step 56800: 0.0307
# WM obs. predictor loss at step 56900: 0.0231
# WM obs. predictor loss at step 57000: 0.0303
# WM obs. predictor loss at step 57100: 0.0197
# WM obs. predictor loss at step 57200: 0.0129
# WM obs. predictor loss at step 57300: 0.0448
# WM obs. predictor loss at step 57400: 0.0460
# WM obs. predictor loss at step 57500: 0.0265
# WM obs. predictor loss at step 57600: 0.0699
# WM obs. predictor loss at step 57700: 0.0393
# WM obs. predictor loss at step 57800: 0.0353
# WM obs. predictor loss at step 57900: 0.0212
# WM obs. predictor loss at step 58000: 0.0535
# WM obs. predictor loss at step 58100: 0.0043
# WM obs. predictor loss at step 58200: 0.0297
# WM obs. predictor loss at step 58300: 0.0319
# WM obs. predictor loss at step 58400: 0.0563
# WM obs. predictor loss at step 58500: 0.0419
# WM obs. predictor loss at step 58600: 0.0248
# WM obs. predictor loss at step 58700: 0.0354
# WM obs. predictor loss at step 58800: 0.0649
# WM obs. predictor loss at step 58900: 0.0536
# WM obs. predictor loss at step 59000: 0.0639
# WM obs. predictor loss at step 59100: 0.0585
# WM obs. predictor loss at step 59200: 0.0326
# WM obs. predictor loss at step 59300: 0.0217
# WM obs. predictor loss at step 59400: 0.0917
# WM obs. predictor loss at step 59500: 0.0324
# WM obs. predictor loss at step 59600: 0.0286
# WM obs. predictor loss at step 59700: 0.0536
# WM obs. predictor loss at step 59800: 0.0527
# WM obs. predictor loss at step 59900: 0.0606
# WM obs. predictor loss at step 60000: 0.0242
# WM obs. predictor loss at step 60100: 0.0404
# WM obs. predictor loss at step 60200: 0.0124
# WM obs. predictor loss at step 60300: 0.0451
# WM obs. predictor loss at step 60400: 0.0272
# WM obs. predictor loss at step 60500: 0.0397
# WM obs. predictor loss at step 60600: 0.0544
# WM obs. predictor loss at step 60700: 0.0434
# WM obs. predictor loss at step 60800: 0.0122
# WM obs. predictor loss at step 60900: 0.0579
# WM obs. predictor loss at step 61000: 0.0199
# WM obs. predictor loss at step 61100: 0.0226
# WM obs. predictor loss at step 61200: 0.0421
# WM obs. predictor loss at step 61300: 0.0488
# WM obs. predictor loss at step 61400: 0.0124
# WM obs. predictor loss at step 61500: 0.0329
# WM obs. predictor loss at step 61600: 0.0372
# WM obs. predictor loss at step 61700: 0.0345
# WM obs. predictor loss at step 61800: 0.0568
# WM obs. predictor loss at step 61900: 0.0754
# WM obs. predictor loss at step 62000: 0.0750
# WM obs. predictor loss at step 62100: 0.0510
# WM obs. predictor loss at step 62200: 0.0042
# WM obs. predictor loss at step 62300: 0.0265
# WM obs. predictor loss at step 62400: 0.0087
# WM obs. predictor loss at step 62500: 0.0864
# WM obs. predictor loss at step 62600: 0.0294
# WM obs. predictor loss at step 62700: 0.0962
# WM obs. predictor loss at step 62800: 0.0710
# WM obs. predictor loss at step 62900: 0.0509
# WM obs. predictor loss at step 63000: 0.0583
# WM obs. predictor loss at step 63100: 0.0497
# WM obs. predictor loss at step 63200: 0.0219
# WM obs. predictor loss at step 63300: 0.0126
# WM obs. predictor loss at step 63400: 0.0400
# WM obs. predictor loss at step 63500: 0.0276
# WM obs. predictor loss at step 63600: 0.0632
# WM obs. predictor loss at step 63700: 0.0442
# WM obs. predictor loss at step 63800: 0.0474
# WM obs. predictor loss at step 63900: 0.0705
# WM obs. predictor loss at step 64000: 0.0548
# WM obs. predictor loss at step 64100: 0.0227
# WM obs. predictor loss at step 64200: 0.1273
# WM obs. predictor loss at step 64300: 0.0449
# WM obs. predictor loss at step 64400: 0.0250
# WM obs. predictor loss at step 64500: 0.0573
# WM obs. predictor loss at step 64600: 0.0566
# WM obs. predictor loss at step 64700: 0.0671
# WM obs. predictor loss at step 64800: 0.0254
# WM obs. predictor loss at step 64900: 0.0863
# WM obs. predictor loss at step 65000: 0.0501
# WM obs. predictor loss at step 65100: 0.0385
# WM obs. predictor loss at step 65200: 0.0402
# WM obs. predictor loss at step 65300: 0.0387
# WM obs. predictor loss at step 65400: 0.0064
# WM obs. predictor loss at step 65500: 0.0261
# WM obs. predictor loss at step 65600: 0.0852
# WM obs. predictor loss at step 65700: 0.0313
# WM obs. predictor loss at step 65800: 0.0519
# WM obs. predictor loss at step 65900: 0.0295
# WM obs. predictor loss at step 66000: 0.0558
# WM obs. predictor loss at step 66100: 0.0496
# WM obs. predictor loss at step 66200: 0.0512
# WM obs. predictor loss at step 66300: 0.0372
# WM obs. predictor loss at step 66400: 0.0379
# WM obs. predictor loss at step 66500: 0.0884
# WM obs. predictor loss at step 66600: 0.0250
# WM obs. predictor loss at step 66700: 0.0521
# WM obs. predictor loss at step 66800: 0.0129
# WM obs. predictor loss at step 66900: 0.0807
# WM obs. predictor loss at step 67000: 0.0153
# WM obs. predictor loss at step 67100: 0.0362
# WM obs. predictor loss at step 67200: 0.0785
# WM obs. predictor loss at step 67300: 0.0839
# WM obs. predictor loss at step 67400: 0.0239
# WM obs. predictor loss at step 67500: 0.0894
# WM obs. predictor loss at step 67600: 0.0163
# WM obs. predictor loss at step 67700: 0.0344
# WM obs. predictor loss at step 67800: 0.0714
# WM obs. predictor loss at step 67900: 0.0725
# WM obs. predictor loss at step 68000: 0.0327
# WM obs. predictor loss at step 68100: 0.0668
# WM obs. predictor loss at step 68200: 0.0486
# WM obs. predictor loss at step 68300: 0.0434
# WM obs. predictor loss at step 68400: 0.0433
# WM obs. predictor loss at step 68500: 0.0691
# WM obs. predictor loss at step 68600: 0.0402
# WM obs. predictor loss at step 68700: 0.0086
# WM obs. predictor loss at step 68800: 0.0504
# WM obs. predictor loss at step 68900: 0.0036
# WM obs. predictor loss at step 69000: 0.0269
# WM obs. predictor loss at step 69100: 0.0353
# WM obs. predictor loss at step 69200: 0.0719
# WM obs. predictor loss at step 69300: 0.0167
# WM obs. predictor loss at step 69400: 0.0866
# WM obs. predictor loss at step 69500: 0.0136
# WM obs. predictor loss at step 69600: 0.0405
# WM obs. predictor loss at step 69700: 0.0932
# WM obs. predictor loss at step 69800: 0.0212
# WM obs. predictor loss at step 69900: 0.0389
# WM obs. predictor loss at step 70000: 0.0553
# WM obs. predictor loss at step 70100: 0.0269
# WM obs. predictor loss at step 70200: 0.0333
# WM obs. predictor loss at step 70300: 0.0236
# WM obs. predictor loss at step 70400: 0.0495
# WM obs. predictor loss at step 70500: 0.0343
# WM obs. predictor loss at step 70600: 0.0217
# WM obs. predictor loss at step 70700: 0.0673
# WM obs. predictor loss at step 70800: 0.0283
# WM obs. predictor loss at step 70900: 0.0388
# WM obs. predictor loss at step 71000: 0.0322
# WM obs. predictor loss at step 71100: 0.0223
# WM obs. predictor loss at step 71200: 0.0256
# WM obs. predictor loss at step 71300: 0.0518
# WM obs. predictor loss at step 71400: 0.0435
# WM obs. predictor loss at step 71500: 0.0809
# WM obs. predictor loss at step 71600: 0.0379
# WM obs. predictor loss at step 71700: 0.0224
# WM obs. predictor loss at step 71800: 0.0396
# WM obs. predictor loss at step 71900: 0.0411
# WM obs. predictor loss at step 72000: 0.0503
# WM obs. predictor loss at step 72100: 0.0408
# WM obs. predictor loss at step 72200: 0.0187
# WM obs. predictor loss at step 72300: 0.0939
# WM obs. predictor loss at step 72400: 0.0231
# WM obs. predictor loss at step 72500: 0.0479
# WM obs. predictor loss at step 72600: 0.0287
# WM obs. predictor loss at step 72700: 0.0155
# WM obs. predictor loss at step 72800: 0.0265
# WM obs. predictor loss at step 72900: 0.0511
# WM obs. predictor loss at step 73000: 0.0370
# WM obs. predictor loss at step 73100: 0.0736
# WM obs. predictor loss at step 73200: 0.0266
# WM obs. predictor loss at step 73300: 0.0311
# WM obs. predictor loss at step 73400: 0.0204
# WM obs. predictor loss at step 73500: 0.0716
# WM obs. predictor loss at step 73600: 0.0254
# WM obs. predictor loss at step 73700: 0.0850
# WM obs. predictor loss at step 73800: 0.0806
# WM obs. predictor loss at step 73900: 0.0223
# WM obs. predictor loss at step 74000: 0.0184
# WM obs. predictor loss at step 74100: 0.0172
# WM obs. predictor loss at step 74200: 0.0209
# WM obs. predictor loss at step 74300: 0.0347
# WM obs. predictor loss at step 74400: 0.0182
# WM obs. predictor loss at step 74500: 0.0275
# WM obs. predictor loss at step 74600: 0.0880
# WM obs. predictor loss at step 74700: 0.0480
# WM obs. predictor loss at step 74800: 0.0198
# WM obs. predictor loss at step 74900: 0.0642
# WM obs. predictor loss at step 75000: 0.1106
# WM obs. predictor loss at step 75100: 0.1238
# WM obs. predictor loss at step 75200: 0.0262
# WM obs. predictor loss at step 75300: 0.0395
# WM obs. predictor loss at step 75400: 0.0625
# WM obs. predictor loss at step 75500: 0.0544
# WM obs. predictor loss at step 75600: 0.0643
# WM obs. predictor loss at step 75700: 0.0348
# WM obs. predictor loss at step 75800: 0.0605
# WM obs. predictor loss at step 75900: 0.0635
# WM obs. predictor loss at step 76000: 0.0560
# WM obs. predictor loss at step 76100: 0.0240
# WM obs. predictor loss at step 76200: 0.0570
# WM obs. predictor loss at step 76300: 0.0500
# WM obs. predictor loss at step 76400: 0.0388
# WM obs. predictor loss at step 76500: 0.0216
# WM obs. predictor loss at step 76600: 0.0913
# WM obs. predictor loss at step 76700: 0.0237
# WM obs. predictor loss at step 76800: 0.0425
# WM obs. predictor loss at step 76900: 0.0555
# WM obs. predictor loss at step 77000: 0.1379
# WM obs. predictor loss at step 77100: 0.0340
# WM obs. predictor loss at step 77200: 0.0249
# WM obs. predictor loss at step 77300: 0.0616
# WM obs. predictor loss at step 77400: 0.0613
# WM obs. predictor loss at step 77500: 0.0243
# WM obs. predictor loss at step 77600: 0.0330
# WM obs. predictor loss at step 77700: 0.0373
# WM obs. predictor loss at step 77800: 0.0574
# WM obs. predictor loss at step 77900: 0.0530
# WM obs. predictor loss at step 78000: 0.0314
# WM obs. predictor loss at step 78100: 0.0264
# WM obs. predictor loss at step 78200: 0.0255
# WM obs. predictor loss at step 78300: 0.0591
# WM obs. predictor loss at step 78400: 0.0293
# WM obs. predictor loss at step 78500: 0.0194
# WM obs. predictor loss at step 78600: 0.0338
# WM obs. predictor loss at step 78700: 0.0424
# WM obs. predictor loss at step 78800: 0.0459
# WM obs. predictor loss at step 78900: 0.0269
# WM obs. predictor loss at step 79000: 0.0828
# WM obs. predictor loss at step 79100: 0.0282
# WM obs. predictor loss at step 79200: 0.0280
# WM obs. predictor loss at step 79300: 0.0495
# WM obs. predictor loss at step 79400: 0.0321
# WM obs. predictor loss at step 79500: 0.0337
# WM obs. predictor loss at step 79600: 0.0726
# WM obs. predictor loss at step 79700: 0.0506
# WM obs. predictor loss at step 79800: 0.0427
# WM obs. predictor loss at step 79900: 0.0646
# WM obs. predictor loss at step 80000: 0.0170
# WM obs. predictor loss at step 80100: 0.0418
# WM obs. predictor loss at step 80200: 0.1116
# WM obs. predictor loss at step 80300: 0.0199
# WM obs. predictor loss at step 80400: 0.0264
# WM obs. predictor loss at step 80500: 0.0292
# WM obs. predictor loss at step 80600: 0.0336
# WM obs. predictor loss at step 80700: 0.0707
# WM obs. predictor loss at step 80800: 0.0296
# WM obs. predictor loss at step 80900: 0.0259
# WM obs. predictor loss at step 81000: 0.0246
# WM obs. predictor loss at step 81100: 0.0453
# WM obs. predictor loss at step 81200: 0.0373
# WM obs. predictor loss at step 81300: 0.0359
# WM obs. predictor loss at step 81400: 0.0463
# WM obs. predictor loss at step 81500: 0.0451
# WM obs. predictor loss at step 81600: 0.0364
# WM obs. predictor loss at step 81700: 0.0077
# WM obs. predictor loss at step 81800: 0.0254
# WM obs. predictor loss at step 81900: 0.0532
# WM obs. predictor loss at step 82000: 0.0770
# WM obs. predictor loss at step 82100: 0.0452
# WM obs. predictor loss at step 82200: 0.0106
# WM obs. predictor loss at step 82300: 0.0281
# WM obs. predictor loss at step 82400: 0.0798
# WM obs. predictor loss at step 82500: 0.0651
# WM obs. predictor loss at step 82600: 0.0163
# WM obs. predictor loss at step 82700: 0.0027
# WM obs. predictor loss at step 82800: 0.0311
# WM obs. predictor loss at step 82900: 0.0260
# WM obs. predictor loss at step 83000: 0.0622
# WM obs. predictor loss at step 83100: 0.0635
# WM obs. predictor loss at step 83200: 0.0672
# WM obs. predictor loss at step 83300: 0.0565
# WM obs. predictor loss at step 83400: 0.0178
# WM obs. predictor loss at step 83500: 0.0212
# WM obs. predictor loss at step 83600: 0.0701
# WM obs. predictor loss at step 83700: 0.0093
# WM obs. predictor loss at step 83800: 0.0545
# WM obs. predictor loss at step 83900: 0.0606
# WM obs. predictor loss at step 84000: 0.0801
# WM obs. predictor loss at step 84100: 0.0244
# WM obs. predictor loss at step 84200: 0.0141
# WM obs. predictor loss at step 84300: 0.0539
# WM obs. predictor loss at step 84400: 0.0235
# WM obs. predictor loss at step 84500: 0.0255
# WM obs. predictor loss at step 84600: 0.0783
# WM obs. predictor loss at step 84700: 0.0375
# WM obs. predictor loss at step 84800: 0.0289
# WM obs. predictor loss at step 84900: 0.0237
# WM obs. predictor loss at step 85000: 0.0187
# WM obs. predictor loss at step 85100: 0.0745
# WM obs. predictor loss at step 85200: 0.0320
# WM obs. predictor loss at step 85300: 0.0497
# WM obs. predictor loss at step 85400: 0.0334
# WM obs. predictor loss at step 85500: 0.0251
# WM obs. predictor loss at step 85600: 0.0419
# WM obs. predictor loss at step 85700: 0.0193
# WM obs. predictor loss at step 85800: 0.0595
# WM obs. predictor loss at step 85900: 0.0136
# WM obs. predictor loss at step 86000: 0.0742
# WM obs. predictor loss at step 86100: 0.0919
# WM obs. predictor loss at step 86200: 0.0807
# WM obs. predictor loss at step 86300: 0.0449
# WM obs. predictor loss at step 86400: 0.1083
# WM obs. predictor loss at step 86500: 0.0117
# WM obs. predictor loss at step 86600: 0.0490
# WM obs. predictor loss at step 86700: 0.0117
# WM obs. predictor loss at step 86800: 0.0377
# WM obs. predictor loss at step 86900: 0.0079
# WM obs. predictor loss at step 87000: 0.0379
# WM obs. predictor loss at step 87100: 0.0376
# WM obs. predictor loss at step 87200: 0.0584
# WM obs. predictor loss at step 87300: 0.0460
# WM obs. predictor loss at step 87400: 0.0986
# WM obs. predictor loss at step 87500: 0.0456
# WM obs. predictor loss at step 87600: 0.0397
# WM obs. predictor loss at step 87700: 0.0363
# WM obs. predictor loss at step 87800: 0.0663
# WM obs. predictor loss at step 87900: 0.0658
# WM obs. predictor loss at step 88000: 0.0703
# WM obs. predictor loss at step 88100: 0.0414
# WM obs. predictor loss at step 88200: 0.0219
# WM obs. predictor loss at step 88300: 0.0328
# WM obs. predictor loss at step 88400: 0.0416
# WM obs. predictor loss at step 88500: 0.0149
# WM obs. predictor loss at step 88600: 0.0439
# WM obs. predictor loss at step 88700: 0.0447
# WM obs. predictor loss at step 88800: 0.0444
# WM obs. predictor loss at step 88900: 0.0580
# WM obs. predictor loss at step 89000: 0.0157
# WM obs. predictor loss at step 89100: 0.1044
# WM obs. predictor loss at step 89200: 0.0635
# WM obs. predictor loss at step 89300: 0.0935
# WM obs. predictor loss at step 89400: 0.0414
# WM obs. predictor loss at step 89500: 0.0706
# WM obs. predictor loss at step 89600: 0.0325
# WM obs. predictor loss at step 89700: 0.0319
# WM obs. predictor loss at step 89800: 0.0842
# WM obs. predictor loss at step 89900: 0.0540
# WM obs. predictor loss at step 90000: 0.0294
# WM obs. predictor loss at step 90100: 0.0242
# WM obs. predictor loss at step 90200: 0.0621
# WM obs. predictor loss at step 90300: 0.0571
# WM obs. predictor loss at step 90400: 0.0076
# WM obs. predictor loss at step 90500: 0.0532
# WM obs. predictor loss at step 90600: 0.0262
# WM obs. predictor loss at step 90700: 0.0690
# WM obs. predictor loss at step 90800: 0.0501
# WM obs. predictor loss at step 90900: 0.0377
# WM obs. predictor loss at step 91000: 0.0438
# WM obs. predictor loss at step 91100: 0.0657
# WM obs. predictor loss at step 91200: 0.0137
# WM obs. predictor loss at step 91300: 0.0496
# WM obs. predictor loss at step 91400: 0.0286
# WM obs. predictor loss at step 91500: 0.0181
# WM obs. predictor loss at step 91600: 0.0609
# WM obs. predictor loss at step 91700: 0.0216
# WM obs. predictor loss at step 91800: 0.1130
# WM obs. predictor loss at step 91900: 0.0680
# WM obs. predictor loss at step 92000: 0.0295
# WM obs. predictor loss at step 92100: 0.0327
# WM obs. predictor loss at step 92200: 0.0436
# WM obs. predictor loss at step 92300: 0.0194
# WM obs. predictor loss at step 92400: 0.0466
# WM obs. predictor loss at step 92500: 0.0230
# WM obs. predictor loss at step 92600: 0.0599
# WM obs. predictor loss at step 92700: 0.0190
# WM obs. predictor loss at step 92800: 0.0345
# WM obs. predictor loss at step 92900: 0.0411
# WM obs. predictor loss at step 93000: 0.1056
# WM obs. predictor loss at step 93100: 0.0242
# WM obs. predictor loss at step 93200: 0.0113
# WM obs. predictor loss at step 93300: 0.0524
# WM obs. predictor loss at step 93400: 0.0396
# WM obs. predictor loss at step 93500: 0.0351
# WM obs. predictor loss at step 93600: 0.0137
# WM obs. predictor loss at step 93700: 0.0606
# WM obs. predictor loss at step 93800: 0.0201
# WM obs. predictor loss at step 93900: 0.0289
# WM obs. predictor loss at step 94000: 0.0441
# WM obs. predictor loss at step 94100: 0.0434
# WM obs. predictor loss at step 94200: 0.0567
# WM obs. predictor loss at step 94300: 0.0560
# WM obs. predictor loss at step 94400: 0.0408
# WM obs. predictor loss at step 94500: 0.0865
# WM obs. predictor loss at step 94600: 0.0346
# WM obs. predictor loss at step 94700: 0.0192
# WM obs. predictor loss at step 94800: 0.0651
# WM obs. predictor loss at step 94900: 0.0655
# WM obs. predictor loss at step 95000: 0.0507
# WM obs. predictor loss at step 95100: 0.0845
# WM obs. predictor loss at step 95200: 0.0435
# WM obs. predictor loss at step 95300: 0.0710
# WM obs. predictor loss at step 95400: 0.0271
# WM obs. predictor loss at step 95500: 0.0584
# WM obs. predictor loss at step 95600: 0.0480
# WM obs. predictor loss at step 95700: 0.0252
# WM obs. predictor loss at step 95800: 0.0733
# WM obs. predictor loss at step 95900: 0.0306
# WM obs. predictor loss at step 96000: 0.0339
# WM obs. predictor loss at step 96100: 0.0276
# WM obs. predictor loss at step 96200: 0.0758
# WM obs. predictor loss at step 96300: 0.0652
# WM obs. predictor loss at step 96400: 0.0193
# WM obs. predictor loss at step 96500: 0.0423
# WM obs. predictor loss at step 96600: 0.0401
# WM obs. predictor loss at step 96700: 0.0463
# WM obs. predictor loss at step 96800: 0.0652
# WM obs. predictor loss at step 96900: 0.0179
# WM obs. predictor loss at step 97000: 0.0116
# WM obs. predictor loss at step 97100: 0.0558
# WM obs. predictor loss at step 97200: 0.0729
# WM obs. predictor loss at step 97300: 0.0816
# WM obs. predictor loss at step 97400: 0.0094
# WM obs. predictor loss at step 97500: 0.0377
# WM obs. predictor loss at step 97600: 0.0192
# WM obs. predictor loss at step 97700: 0.0588
# WM obs. predictor loss at step 97800: 0.0261
# WM obs. predictor loss at step 97900: 0.0353
# WM obs. predictor loss at step 98000: 0.0789
# WM obs. predictor loss at step 98100: 0.0361
# WM obs. predictor loss at step 98200: 0.0403
# WM obs. predictor loss at step 98300: 0.0924
# WM obs. predictor loss at step 98400: 0.0807
# WM obs. predictor loss at step 98500: 0.0190
# WM obs. predictor loss at step 98600: 0.0665
# WM obs. predictor loss at step 98700: 0.0643
# WM obs. predictor loss at step 98800: 0.0281
# WM obs. predictor loss at step 98900: 0.0160
# WM obs. predictor loss at step 99000: 0.0069
# WM obs. predictor loss at step 99100: 0.0344
# WM obs. predictor loss at step 99200: 0.0593
# WM obs. predictor loss at step 99300: 0.0221
# WM obs. predictor loss at step 99400: 0.0360
# WM obs. predictor loss at step 99500: 0.0780
# WM obs. predictor loss at step 99600: 0.0856
# WM obs. predictor loss at step 99700: 0.0167
# WM obs. predictor loss at step 99800: 0.0715
# WM obs. predictor loss at step 99900: 0.0031
